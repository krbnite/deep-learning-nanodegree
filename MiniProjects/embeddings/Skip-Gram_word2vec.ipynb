# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:10, 2.96MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
# Wow, I started by using a dictionary comprehension, but it took forever...  The sol'n uses a Counter() object
# imported from {collections}.  It take a couple seconds to fully run...
# uniq_words = set(words)
# word_freqs = {word: words.count(word) for word in uniq_words}

from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
min(0,2)
# Out:
# 0

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = random.choice(list(range(1,window_size+1)))
    lower_bound = max(0, idx-R)
    upper_bound = min(idx+R, len(words))
    frame = words[lower_bound:idx]+words[idx+1:upper_bound]
    return(frame)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a **generator function** by the way, **helps save memory**.

# %%
# By using a generator function, only one batch need be in memory at any given time.

def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    '''Fill in code'''
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6209 0.4692 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5541 0.4335 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4336 0.4373 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5511 0.4340 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4679 0.4382 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4891 0.4681 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5492 0.4920 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5259 0.4594 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4857 0.4765 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3964 0.4600 sec/batch
# Nearest to no: harmattan, lutheranism, incompatibilities, galante, generalissimo, afforded, cleaned, detract,
# Nearest to such: mercenaries, forearm, bluetooth, automobile, sizable, jupiter, marienburg, disciplines,
# Nearest to while: rosencrantz, inductors, tails, hypothetically, exchanging, degenerative, pulmonic, vodun,
# Nearest to he: saadia, misperception, antinous, winemaking, minivans, admission, premise, illiterate,
# Nearest to about: thessalonians, giger, rectum, plunder, prez, kristen, supine, pressures,
# Nearest to up: captured, hindi, minorities, metrics, alp, eponymous, teaser, nizkor,
# Nearest to an: minstrel, saloons, lie, skydiving, cameos, renan, epiphenomenalism, lojban,
# Nearest to zero: oz, meld, emphasis, speeding, delicacy, phoenicia, conditioning, simplicity,
# Nearest to assembly: piazzi, instability, masterpiece, reason, incident, bolsters, railhead, synclavier,
# Nearest to award: chaco, alleged, batcave, directory, traditionalists, has, placenta, cavendish,
# Nearest to universe: modestly, arabia, speaks, gritty, materials, gondry, lowie, landlord,
# Nearest to units: charley, determine, illuminating, rejects, smalley, apologised, suevi, variant,
# Nearest to numerous: halley, moist, penicillium, langmuir, spaniard, ven, bund, otherworldly,
# Nearest to bbc: notched, levies, deoxygenated, symbolism, visitor, premier, moreau, florence,
# Nearest to alternative: misdemeanors, twentieth, wien, suvs, successor, anagrams, brahmaputra, anabolic,
# Nearest to recorded: couper, shell, qu, plans, manon, constantly, quirin, johnstown,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4470 0.4831 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3763 0.4910 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3156 0.4318 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2507 0.4324 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1670 0.4327 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2010 0.4330 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1212 0.4342 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1084 0.4371 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0429 0.4329 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0077 0.4335 sec/batch
# Nearest to no: including, nickname, harmattan, lutheranism, peoples, virtually, includes, cleaned,
# Nearest to such: automobile, mercenaries, disciplines, increases, alternately, kent, america, otherwise,
# Nearest to while: rosencrantz, tails, inductors, hypothetically, explicitly, devil, true, exchanging,
# Nearest to he: admission, premiered, premise, saadia, pluralism, illiterate, driven, required,
# Nearest to about: thessalonians, pressures, bc, simply, plunder, rectum, skip, resistant,
# Nearest to up: captured, minorities, metrics, hindi, eponymous, my, individuals, wavelength,
# Nearest to an: minerals, minstrel, lie, competition, refusing, saloons, brigades, attributed,
# Nearest to zero: oz, emphasis, formally, fast, trend, mainland, left, simplicity,
# Nearest to assembly: reason, instability, incident, masterpiece, piazzi, fires, advancing, accomplishing,
# Nearest to award: chaco, alleged, has, directory, batcave, placenta, warped, diagnose,
# Nearest to universe: modestly, materials, speaks, arabia, gondry, sharper, landlord, tens,
# Nearest to units: determine, its, variant, charley, rejects, championship, smalley, according,
# Nearest to numerous: halley, terminals, bund, penicillium, pop, louvain, phil, moist,
# Nearest to bbc: notched, levies, visitor, symbolism, premier, armchair, florence, moreau,
# Nearest to alternative: twentieth, duly, successor, algorithms, decline, france, pantheons, thunderbolt,
# Nearest to recorded: plans, couper, shell, qu, constantly, manon, red, piano,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9784 0.4401 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9109 0.4337 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9191 0.4343 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8901 0.4324 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8308 0.4377 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8280 0.4338 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8155 0.4451 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7954 0.4385 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8143 0.4623 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7880 0.4379 sec/batch
# Nearest to no: lutheranism, nickname, harmattan, cleaned, resolves, afforded, peoples, incompatibilities,
# Nearest to such: automobile, disciplines, mercenaries, alternately, increases, kent, jupiter, sizable,
# Nearest to while: rosencrantz, tails, hypothetically, inductors, exchanging, degenerative, involve, explicitly,
# Nearest to he: premiered, admission, eds, driven, premise, pug, illiterate, contributing,
# Nearest to about: thessalonians, inland, pressures, producing, plunder, giger, excess, freely,
# Nearest to up: captured, minorities, metrics, hindi, eponymous, occupies, breezes, alp,
# Nearest to an: lie, inputs, refusing, minstrel, competition, cameos, brigades, minerals,
# Nearest to zero: mainland, oz, mortality, simplicity, emphasis, trend, formally, speeding,
# Nearest to assembly: instability, reason, masterpiece, incident, piazzi, accomplishing, advancing, prelude,
# Nearest to award: alleged, has, directory, chaco, batcave, international, solvents, apes,
# Nearest to universe: materials, modestly, arabia, speaks, tens, landlord, sharper, gondry,
# Nearest to units: determine, variant, its, championship, charley, rejects, exponents, fix,
# Nearest to numerous: halley, bund, pop, moist, terminals, spaniard, phil, bel,
# Nearest to bbc: notched, visitor, symbolism, premier, levies, armchair, embarrassment, moreau,
# Nearest to alternative: twentieth, algorithms, successor, duly, decline, suvs, views, wien,
# Nearest to recorded: couper, shell, constantly, plans, qu, piano, peasants, manon,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7657 0.4459 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7694 0.4434 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7114 0.4382 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7107 0.4374 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7605 0.4382 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7244 0.4401 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7348 0.4370 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7236 0.4378 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6945 0.4421 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6564 0.4374 sec/batch
# Nearest to no: lutheranism, incompatibilities, afforded, harmattan, generalissimo, detract, twilight, cleaned,
# Nearest to such: disciplines, mercenaries, forearm, automobile, alternately, increases, lgpl, sizable,
# Nearest to while: rosencrantz, inductors, tails, hypothetically, exchanging, teutonic, pragmatism, degenerative,
# Nearest to he: pug, premiered, admission, pluralism, joyce, frees, eds, saadia,
# Nearest to about: thessalonians, plunder, inland, pressures, cigarette, skip, producing, giger,
# Nearest to up: captured, metrics, hindi, minorities, alp, breezes, occupies, nizkor,
# Nearest to an: lie, cameos, inputs, minstrel, animosity, saloons, skydiving, irreducible,
# Nearest to zero: mainland, three, mortality, oz, harper, formally, speeding, delicacy,
# Nearest to assembly: instability, piazzi, reason, incident, masterpiece, accomplishing, synclavier, detachment,
# Nearest to award: alleged, chaco, directory, apes, solvents, has, batcave, introducing,
# Nearest to universe: materials, arabia, modestly, speaks, gondry, gritty, reassure, mansion,
# Nearest to units: variant, determine, championship, its, illuminating, rejects, charley, exponents,
# Nearest to numerous: halley, moist, pop, spaniard, bel, bund, louvain, penicillium,
# Nearest to bbc: notched, levies, premier, visitor, symbolism, moreau, breatharianism, thirteen,
# Nearest to alternative: twentieth, wien, suvs, algorithms, misdemeanors, duly, views, decline,
# Nearest to recorded: couper, constantly, shell, plans, qu, piano, peasants, manon,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6660 0.4446 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6644 0.4378 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6157 0.4369 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6385 0.4377 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6406 0.4384 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6153 0.4427 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6054 0.3275 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5682 0.4368 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5002 0.4366 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5129 0.4375 sec/batch
# Nearest to no: lutheranism, afforded, incompatibilities, detract, harmattan, generalissimo, cleaned, brunt,
# Nearest to such: disciplines, increases, forearm, does, alternately, fanfic, lgpl, types,
# Nearest to while: rosencrantz, inductors, exchanging, tails, pragmatism, hypothetically, true, teutonic,
# Nearest to he: pug, premiered, misperception, admission, illiterate, pluralism, frees, brawling,
# Nearest to about: thessalonians, inland, plunder, cigarette, truncated, giger, skip, symbol,
# Nearest to up: captured, metrics, hindi, breezes, alp, minorities, ichij, marine,
# Nearest to an: cameos, minstrel, lie, inputs, irreducible, saloons, sore, be,
# Nearest to zero: three, mainland, mortality, seven, oz, harper, alimony, grt,
# Nearest to assembly: instability, reason, masterpiece, piazzi, incident, pleases, synclavier, legislative,
# Nearest to award: alleged, chaco, cavendish, apes, batcave, mecklenburg, kettle, oscar,
# Nearest to universe: materials, arabia, speaks, gondry, modestly, landlord, lowie, chokes,
# Nearest to units: variant, determine, illuminating, its, championship, exponents, biplanes, hv,
# Nearest to numerous: halley, moist, louvain, penicillium, pop, srinivasa, otherworldly, engendered,
# Nearest to bbc: notched, premier, levies, moreau, visitor, thirteen, geysers, breatharianism,
# Nearest to alternative: twentieth, algorithms, misdemeanors, suvs, laserdisc, wien, pantheons, insemination,
# Nearest to recorded: couper, constantly, plans, qu, piano, shell, solidify, manon,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4777 0.4436 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4959 0.4374 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4603 0.4425 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5035 0.4366 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4755 0.4379 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4611 0.4478 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4562 0.4491 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4191 0.4548 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4305 0.4510 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4099 0.4491 sec/batch
# Nearest to no: incompatibilities, lutheranism, detract, afforded, fact, generalissimo, galante, try,
# Nearest to such: disciplines, increases, forearm, bluetooth, fanfic, lgpl, alternately, smallest,
# Nearest to while: rosencrantz, inductors, tails, vodun, exchanging, pragmatism, teutonic, hypothetically,
# Nearest to he: pug, premiered, admission, brawling, frees, misperception, constance, pluralism,
# Nearest to about: inland, thessalonians, plunder, composting, cigarette, symbol, truncated, pressures,
# Nearest to up: captured, breezes, metrics, hindi, alp, include, ichij, eugenio,
# Nearest to an: inputs, irreducible, saloons, minstrel, lie, be, cameos, renan,
# Nearest to zero: three, mortality, seven, mainland, est, male, harper, grt,
# Nearest to assembly: legislative, instability, virginian, executive, synclavier, electors, piazzi, conservative,
# Nearest to award: chaco, alleged, batcave, apes, cavendish, oscar, superman, mecklenburg,
# Nearest to universe: materials, fleeting, speaks, arabia, gondry, cypher, chokes, gritty,
# Nearest to units: variant, determine, illuminating, its, exponents, biplanes, kw, championship,
# Nearest to numerous: halley, moist, bel, otherworldly, sealing, louvain, penicillium, prolonging,
# Nearest to bbc: notched, premier, visitor, breatharianism, geysers, moreau, thirteen, levies,
# Nearest to alternative: twentieth, algorithms, laserdisc, suvs, insemination, misdemeanors, wien, outlines,
# Nearest to recorded: couper, constantly, piano, plans, qu, manon, shell, solidify,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4574 0.4574 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3921 0.4485 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4416 0.4513 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4145 0.4504 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3939 0.4562 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4456 0.4558 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3653 0.4528 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3930 0.4517 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4086 0.4512 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3767 0.4532 sec/batch
# Nearest to no: lutheranism, incompatibilities, detract, afforded, generalissimo, fact, try, brunt,
# Nearest to such: disciplines, increases, bluetooth, forearm, alternately, lgpl, fanfic, automobile,
# Nearest to while: rosencrantz, inductors, tails, vodun, teutonic, pragmatism, exchanging, kylix,
# Nearest to he: premiered, pug, brawling, constance, admission, priestly, frees, misperception,
# Nearest to about: composting, cigarette, thessalonians, inland, homology, plunder, symbol, truncated,
# Nearest to up: captured, breezes, metrics, hindi, arif, alp, cmc, encounter,
# Nearest to an: saloons, lie, irreducible, minstrel, inputs, cameos, be, sore,
# Nearest to zero: three, seven, mortality, est, harper, mainland, male, five,
# Nearest to assembly: legislative, executive, virginian, electors, synclavier, instability, cabinet, requirements,
# Nearest to award: cavendish, batcave, alleged, oscar, superman, chaco, apes, mecklenburg,
# Nearest to universe: materials, fleeting, speaks, conspiracies, cypher, dostum, chokes, lowie,
# Nearest to units: variant, exponents, determine, kw, used, biplanes, its, illuminating,
# Nearest to numerous: halley, otherworldly, moist, bel, louvain, penicillium, sealing, prolonging,
# Nearest to bbc: notched, visitor, geysers, moreau, premier, breatharianism, thirteen, music,
# Nearest to alternative: twentieth, algorithms, wien, laserdisc, insemination, misdemeanors, suvs, anagrams,
# Nearest to recorded: piano, couper, constantly, manon, plans, solidify, shell, batu,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3537 0.4460 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3633 0.4373 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3563 0.4364 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3481 0.4365 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3870 0.4366 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3833 0.4364 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4023 0.4361 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3630 0.4396 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3135 0.4371 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3235 0.4381 sec/batch
# Nearest to no: incompatibilities, lutheranism, detract, afforded, generalissimo, fact, try, approachable,
# Nearest to such: disciplines, bluetooth, lgpl, increases, fanfic, sizable, automobile, forearm,
# Nearest to while: rosencrantz, inductors, vodun, tails, exchanging, kylix, degenerative, teutonic,
# Nearest to he: pug, premiered, brawling, constance, misperception, priestly, admission, frees,
# Nearest to about: inland, composting, homology, thessalonians, cigarette, plunder, symbol, extends,
# Nearest to up: captured, breezes, metrics, arif, alp, cmc, teaser, brilliant,
# Nearest to an: saloons, irreducible, renan, inputs, competition, lie, minstrel, be,
# Nearest to zero: three, seven, est, mortality, na, five, four, mainland,
# Nearest to assembly: legislative, executive, electors, virginian, cabinet, synclavier, instability, rohrabacher,
# Nearest to award: oscar, batcave, cavendish, superman, chine, chaco, alleged, kettle,
# Nearest to universe: materials, dostum, speaks, conspiracies, lowie, agnostics, fleeting, arabia,
# Nearest to units: variant, kw, determine, its, biplanes, exponents, illuminating, used,
# Nearest to numerous: halley, moist, otherworldly, louvain, bel, prolonging, spaniard, sealing,
# Nearest to bbc: notched, visitor, moreau, geysers, premier, breatharianism, foley, compositions,
# Nearest to alternative: twentieth, laserdisc, insemination, algorithms, wien, misdemeanors, outlines, freon,
# Nearest to recorded: couper, piano, constantly, solidify, dardanelles, plans, qu, batu,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3563 0.4413 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3024 0.4379 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3824 0.4372 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3612 0.4354 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3644 0.4401 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2622 0.4357 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2720 0.4659 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3315 0.4373 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2203 0.4376 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2681 0.4395 sec/batch
# Nearest to no: incompatibilities, detract, lutheranism, afforded, generalissimo, approachable, brunt, cures,
# Nearest to such: disciplines, bluetooth, sizable, increases, lgpl, fanfic, forearm, automobile,
# Nearest to while: rosencrantz, inductors, vodun, kylix, nonterminal, tails, teutonic, prefer,
# Nearest to he: pug, premiered, constance, brawling, priestly, trying, misperception, patriotic,
# Nearest to about: composting, inland, cigarette, homology, thessalonians, extends, truncated, beds,
# Nearest to up: captured, breezes, arif, alp, encounter, metrics, cmc, incredibly,
# Nearest to an: saloons, minstrel, lie, typecast, irreducible, renan, be, ripening,
# Nearest to zero: three, seven, two, five, mortality, four, est, eight,
# Nearest to assembly: legislative, executive, cabinet, electors, virginian, unicameral, appoints, proportional,
# Nearest to award: oscar, awards, batcave, barry, bafta, kettle, chine, ska,
# Nearest to universe: materials, dostum, conspiracies, lowie, speaks, agnostics, arabia, fleeting,
# Nearest to units: variant, kw, exponents, determine, its, biplanes, lnot, used,
# Nearest to numerous: halley, moist, louvain, penicillium, bel, otherworldly, srinivasa, sealing,
# Nearest to bbc: notched, visitor, moreau, premier, foley, breatharianism, otis, swaziland,
# Nearest to alternative: laserdisc, twentieth, algorithms, insemination, wien, outlines, ase, misdemeanors,
# Nearest to recorded: piano, couper, constantly, solidify, shell, dardanelles, video, plans,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2763 0.4440 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2889 0.4381 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3381 0.2269 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2154 0.4382 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2056 0.4361 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1790 0.4378 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2077 0.4371 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1830 0.4374 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2124 0.4368 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1665 0.4410 sec/batch
# Nearest to no: incompatibilities, detract, afforded, lutheranism, approachable, brunt, generalissimo, confessio,
# Nearest to such: disciplines, bluetooth, sizable, increases, lgpl, fanfic, lactic, blankets,
# Nearest to while: rosencrantz, inductors, vodun, nonterminal, kylix, prefer, tails, exchanging,
# Nearest to he: pug, constance, premiered, priestly, brawling, trying, his, commanded,
# Nearest to about: inland, composting, extends, cigarette, thessalonians, homology, beds, atx,
# Nearest to up: captured, breezes, arif, cmc, alp, encounter, metrics, brilliant,
# Nearest to an: saloons, renan, typecast, lie, minstrel, competition, refugee, ringgit,
# Nearest to zero: three, seven, two, five, est, eight, four, mortality,
# Nearest to assembly: legislative, executive, cabinet, electors, unicameral, proportional, virginian, appoints,
# Nearest to award: awards, oscar, bafta, batcave, kettle, ska, film, chine,
# Nearest to universe: lowie, conspiracies, agnostics, fleeting, afterglow, dostum, materials, atheos,
# Nearest to units: kw, variant, biplanes, exponents, determine, lnot, illuminating, championship,
# Nearest to numerous: moist, penicillium, louvain, halley, bel, sealing, otherworldly, johnstown,
# Nearest to bbc: notched, visitor, moreau, swaziland, intelligencer, breatharianism, doodles, premier,
# Nearest to alternative: twentieth, laserdisc, algorithms, insemination, outlines, wien, misdemeanors, suvs,
# Nearest to recorded: piano, couper, constantly, adversity, solidify, batu, delights, probe,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2275 0.4450 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1719 0.4391 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2138 0.4358 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1382 0.4401 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1478 0.4378 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1333 0.4375 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1582 0.4435 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1674 0.4474 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1669 0.4401 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1425 0.4376 sec/batch
# Nearest to no: incompatibilities, detract, approachable, afforded, lutheranism, fact, confessio, generalissimo,
# Nearest to such: disciplines, increases, sizable, bluetooth, lgpl, automobile, icons, fanfic,
# Nearest to while: rosencrantz, inductors, nonterminal, kylix, vodun, prefer, exchanging, hypothetically,
# Nearest to he: pug, premiered, constance, his, brawling, priestly, trying, annunciation,
# Nearest to about: inland, composting, cigarette, extends, symbol, homology, thessalonians, beds,
# Nearest to up: captured, breezes, arif, cmc, encounter, crowd, bottom, brilliant,
# Nearest to an: saloons, minstrel, renan, refugee, lie, typecast, be, irreducible,
# Nearest to zero: three, seven, two, five, eight, four, est, six,
# Nearest to assembly: legislative, executive, cabinet, electors, proportional, unicameral, virginian, appoints,
# Nearest to award: awards, bafta, oscar, batcave, ska, kettle, awarded, mcfarland,
# Nearest to universe: fleeting, agnostics, lowie, materials, conspiracies, chokes, homomorphisms, cosmology,
# Nearest to units: variant, kw, exponents, used, biplanes, lnot, championship, illuminating,
# Nearest to numerous: moist, louvain, halley, penicillium, pop, otherworldly, bel, sealing,
# Nearest to bbc: notched, visitor, moreau, collaborated, cremona, kkk, intelligencer, scavenger,
# Nearest to alternative: twentieth, laserdisc, algorithms, outlines, insemination, wien, freon, misdemeanors,
# Nearest to recorded: piano, constantly, couper, batu, solidify, delights, adversity, solo,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1482 0.4437 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2123 0.4371 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1378 0.4438 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1190 0.4419 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1225 0.4553 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1550 0.4501 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1643 0.4506 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1171 0.4525 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1364 0.4546 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1597 0.4495 sec/batch
# Nearest to no: incompatibilities, detract, approachable, afforded, lutheranism, brunt, roused, confessio,
# Nearest to such: disciplines, bluetooth, increases, sizable, lgpl, automobile, icons, lactic,
# Nearest to while: inductors, rosencrantz, prefer, nonterminal, kylix, vodun, exchanging, true,
# Nearest to he: pug, his, priestly, constance, premiered, brawling, was, arrhythmia,
# Nearest to about: inland, composting, extends, cigarette, homology, thessalonians, symbol, beds,
# Nearest to up: captured, arif, breezes, cmc, grill, encounter, brilliant, endgame,
# Nearest to an: minstrel, saloons, renan, skydiving, lie, preexistence, typecast, be,
# Nearest to zero: three, seven, two, five, eight, four, one, six,
# Nearest to assembly: legislative, executive, cabinet, electors, unicameral, proportional, virginian, bicameral,
# Nearest to award: awards, bafta, oscar, batcave, kettle, awarded, introducing, mcfarland,
# Nearest to universe: lowie, agnostics, fleeting, cosmology, afterglow, conspiracies, chokes, arabia,
# Nearest to units: variant, kw, exponents, used, lnot, biplanes, championship, determine,
# Nearest to numerous: louvain, otherworldly, pop, moist, halley, bel, penicillium, frown,
# Nearest to bbc: notched, visitor, moreau, kkk, cremona, scavenger, luthiers, doodles,
# Nearest to alternative: twentieth, laserdisc, algorithms, outlines, insemination, wien, freon, aspects,
# Nearest to recorded: piano, constantly, batu, solidify, couper, adversity, millarca, delights,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1982 0.4555 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1658 0.4517 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1725 0.4506 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1609 0.4496 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1289 0.4512 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1095 0.4610 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1292 0.4514 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1170 0.4476 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1903 0.4361 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1662 0.4357 sec/batch
# Nearest to no: incompatibilities, approachable, detract, lutheranism, afforded, generalissimo, brunt, confessio,
# Nearest to such: sizable, disciplines, lgpl, bluetooth, increases, icons, maasai, corroborating,
# Nearest to while: inductors, prefer, rosencrantz, kylix, vodun, nonterminal, exchanging, erstwhile,
# Nearest to he: pug, his, was, constance, arrhythmia, priestly, premiered, brawling,
# Nearest to about: composting, inland, cigarette, thessalonians, extends, homology, prez, eisenach,
# Nearest to up: captured, arif, breezes, alp, incredibly, cmc, grill, edo,
# Nearest to an: minstrel, refugee, saloons, renan, beatified, unscr, lapsed, preexistence,
# Nearest to zero: three, two, seven, five, four, eight, one, six,
# Nearest to assembly: legislative, executive, proportional, bicameral, unicameral, cabinet, electors, virginian,
# Nearest to award: awards, bafta, oscar, awarded, best, batcave, reeves, introducing,
# Nearest to universe: lowie, agnostics, arabia, afterglow, cosmology, fleeting, cypher, atheos,
# Nearest to units: kw, variant, championship, lnot, islander, biplanes, jamiroquai, determine,
# Nearest to numerous: pop, louvain, otherworldly, moist, halley, penicillium, mustered, spaniard,
# Nearest to bbc: notched, visitor, swaziland, creation, moreau, collaborated, scavenger, doodles,
# Nearest to alternative: twentieth, laserdisc, outlines, wien, hawthorne, insemination, freon, algorithms,
# Nearest to recorded: piano, constantly, couper, batu, solidify, adversity, encamped, memphis,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2079 0.4424 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1191 0.4357 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0983 0.4386 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1331 0.4353 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0050 0.4364 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1104 0.4353 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1138 0.4385 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0976 0.4378 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1537 0.1100 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0867 0.4364 sec/batch
# Nearest to no: incompatibilities, detract, approachable, afforded, lutheranism, hampered, brunt, disintegrates,
# Nearest to such: sizable, disciplines, lgpl, increases, bluetooth, automobile, lactic, icons,
# Nearest to while: inductors, prefer, nonterminal, rosencrantz, vodun, kylix, farad, exchanging,
# Nearest to he: pug, his, arrhythmia, was, constance, unsuccessfully, brawling, trying,
# Nearest to about: composting, inland, cigarette, thessalonians, extends, homology, forays, beds,
# Nearest to up: arif, breezes, captured, grill, alp, cmc, metrics, incredibly,
# Nearest to an: minstrel, refugee, typecast, heterozygosity, ripening, saloons, petrochemical, ringgit,
# Nearest to zero: three, two, seven, five, four, eight, six, one,
# Nearest to assembly: legislative, executive, unicameral, proportional, bicameral, cabinet, seats, appoints,
# Nearest to award: awards, bafta, oscar, awarded, best, film, reeves, ska,
# Nearest to universe: lowie, cosmology, arabia, afterglow, agnostics, fleeting, cypher, humankind,
# Nearest to units: kw, variant, lnot, used, championship, exponents, islander, redefined,
# Nearest to numerous: moist, pop, louvain, penicillium, mustered, sealing, frown, halley,
# Nearest to bbc: notched, visitor, swaziland, creation, moreau, collaborated, doodles, bothnia,
# Nearest to alternative: laserdisc, twentieth, outlines, algorithms, freon, freeform, hawthorne, wien,
# Nearest to recorded: piano, constantly, couper, memphis, solidify, probe, delights, encamped,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0281 0.4447 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0551 0.4362 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0605 0.4363 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0190 0.4342 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0414 0.4363 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9834 0.4380 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0756 0.4362 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0182 0.4350 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1051 0.4375 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9819 0.4375 sec/batch
# Nearest to no: incompatibilities, approachable, detract, afforded, lutheranism, hampered, confessio, brunt,
# Nearest to such: sizable, disciplines, increases, lgpl, japanese, bluetooth, automobile, icons,
# Nearest to while: prefer, inductors, kylix, rosencrantz, nonterminal, vodun, farad, exchanging,
# Nearest to he: pug, his, was, unsuccessfully, priestly, worked, brawling, constance,
# Nearest to about: composting, inland, thessalonians, cigarette, extends, homology, global, forays,
# Nearest to up: arif, breezes, captured, grill, incredibly, cmc, endgame, crowd,
# Nearest to an: refugee, petrochemical, heterozygosity, saloons, typecast, osx, beatified, ringgit,
# Nearest to zero: three, two, five, seven, six, four, eight, one,
# Nearest to assembly: legislative, executive, bicameral, proportional, unicameral, cabinet, appoints, elects,
# Nearest to award: awards, bafta, oscar, awarded, nominated, film, ska, introducing,
# Nearest to universe: cosmology, lowie, agnostics, arabia, quasars, fleeting, afterglow, cypher,
# Nearest to units: kw, variant, used, lnot, islander, championship, biplanes, exponents,
# Nearest to numerous: moist, pop, mustered, louvain, penicillium, sealing, othniel, bel,
# Nearest to bbc: notched, visitor, creation, swaziland, collaborated, bothnia, doodles, moreau,
# Nearest to alternative: twentieth, laserdisc, outlines, freon, clinicians, freeform, aspects, insemination,
# Nearest to recorded: constantly, piano, couper, adversity, delights, memphis, qu, solidify,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0025 0.4424 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0113 0.4361 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9727 0.4397 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0032 0.4358 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9908 0.4413 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0227 0.4351 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0457 0.4359 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0887 0.4386 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0170 0.4361 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9972 0.4412 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, detract, hampered, lutheranism, disintegrates, undue,
# Nearest to such: sizable, increases, icons, automobile, disciplines, bluetooth, japanese, lgpl,
# Nearest to while: prefer, inductors, kylix, nonterminal, exchanging, rosencrantz, hypothetically, insecta,
# Nearest to he: pug, his, worked, was, arrhythmia, brawling, unsuccessfully, trying,
# Nearest to about: composting, thessalonians, cigarette, homology, inland, extends, downy, forays,
# Nearest to up: arif, breezes, grill, captured, bottom, cmc, teaser, clear,
# Nearest to an: be, petrochemical, durians, heterozygosity, lie, furigana, refugee, saloons,
# Nearest to zero: three, five, two, seven, four, six, eight, one,
# Nearest to assembly: legislative, bicameral, executive, unicameral, proportional, cabinet, electors, appoints,
# Nearest to award: awards, bafta, awarded, oscar, nominated, best, ska, introducing,
# Nearest to universe: cosmology, lowie, arabia, agnostics, quasars, afterglow, fleeting, creationism,
# Nearest to units: kw, variant, lnot, used, exponents, islander, championship, biplanes,
# Nearest to numerous: moist, pop, penicillium, louvain, mustered, halley, sealing, othniel,
# Nearest to bbc: notched, visitor, swaziland, creation, collaborated, pbs, bothnia, december,
# Nearest to alternative: twentieth, laserdisc, outlines, freon, clinicians, freeform, wien, hawthorne,
# Nearest to recorded: constantly, piano, memphis, encamped, delights, couper, probe, millarca,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0293 0.4442 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0392 0.4362 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0526 0.4358 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9963 0.4371 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0560 0.4372 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0350 0.4369 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0284 1.9920 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0375 0.4370 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0537 0.4385 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0316 0.4368 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, detract, hampered, lutheranism, roused, leak,
# Nearest to such: sizable, icons, automobile, japanese, increases, bluetooth, entendres, lactic,
# Nearest to while: prefer, inductors, kylix, nonterminal, rosencrantz, exchanging, vodun, revlon,
# Nearest to he: his, pug, was, worked, trying, unsuccessfully, priestly, constance,
# Nearest to about: composting, thessalonians, cigarette, inland, homology, extends, hotspots, paige,
# Nearest to up: arif, captured, grill, clear, revolver, breezes, bottom, sergius,
# Nearest to an: durians, refugee, minstrel, which, heterozygosity, petrochemical, beatified, skydiving,
# Nearest to zero: three, two, five, seven, six, four, one, eight,
# Nearest to assembly: legislative, bicameral, executive, unicameral, proportional, virginian, cabinet, elects,
# Nearest to award: awards, bafta, awarded, oscar, best, nominated, introducing, ska,
# Nearest to universe: cosmology, lowie, quasars, arabia, agnostics, afterglow, fleeting, cypher,
# Nearest to units: kw, lnot, islander, variant, exponents, used, championship, biplanes,
# Nearest to numerous: moist, pop, louvain, penicillium, mustered, shintoism, othniel, decry,
# Nearest to bbc: notched, visitor, creation, doodles, swaziland, pbs, bothnia, collaborated,
# Nearest to alternative: laserdisc, twentieth, freon, outlines, clinicians, freeform, wien, bandy,
# Nearest to recorded: constantly, piano, memphis, solidify, encamped, probe, batu, millarca,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0110 0.4429 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9745 0.4386 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0165 0.4419 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0307 0.4398 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0767 0.4390 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1206 0.4380 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0976 0.4378 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0063 0.4535 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9784 0.4387 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0113 0.4397 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, detract, hampered, roused, archons, lutheranism,
# Nearest to such: sizable, icons, japanese, bluetooth, entendres, automobile, primus, increases,
# Nearest to while: prefer, inductors, nonterminal, kylix, rosencrantz, exchanging, vodun, and,
# Nearest to he: his, pug, was, worked, charred, priestly, hawat, trying,
# Nearest to about: composting, cigarette, thessalonians, inland, homology, extends, vaginal, lessons,
# Nearest to up: arif, clear, breezes, grill, captured, chokes, sergius, incredibly,
# Nearest to an: the, of, durians, refugee, petrochemical, which, beatified, minstrel,
# Nearest to zero: three, two, five, seven, six, four, one, eight,
# Nearest to assembly: legislative, bicameral, unicameral, proportional, executive, virginian, appoints, elects,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, introducing, ska,
# Nearest to universe: arabia, cosmology, lowie, quasars, afterglow, agnostics, atheos, fleeting,
# Nearest to units: kw, islander, lnot, exponents, championship, used, redefined, variant,
# Nearest to numerous: moist, penicillium, pop, louvain, mustered, othniel, shintoism, decry,
# Nearest to bbc: notched, visitor, swaziland, bothnia, creation, overviews, doodles, december,
# Nearest to alternative: laserdisc, twentieth, outlines, hawthorne, wien, clinicians, freon, freeform,
# Nearest to recorded: constantly, piano, memphis, encamped, tumultuous, delights, solidify, aphra,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9202 0.4432 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9863 0.4387 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9986 0.4392 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0172 0.4384 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0144 0.4435 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0017 0.4395 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9918 0.4369 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9358 0.4391 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9585 0.4476 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9328 0.4394 sec/batch
# Nearest to no: incompatibilities, approachable, detract, afforded, hampered, archons, lutheranism, moment,
# Nearest to such: sizable, icons, japanese, entendres, refers, bluetooth, increases, lactic,
# Nearest to while: prefer, nonterminal, exchanging, kylix, inductors, vodun, farad, revlon,
# Nearest to he: his, pug, was, priestly, charred, worked, him, unsuccessfully,
# Nearest to about: composting, thessalonians, inland, cigarette, extends, downy, homology, epiphanes,
# Nearest to up: arif, clear, grill, sergius, captured, breezes, wither, pyre,
# Nearest to an: the, of, petrochemical, which, durians, heterozygosity, furigana, beatified,
# Nearest to zero: three, two, five, seven, six, four, one, eight,
# Nearest to assembly: legislative, bicameral, unicameral, proportional, executive, virginian, appoints, elects,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, ska, introducing,
# Nearest to universe: cosmology, arabia, lowie, quasars, agnostics, afterglow, cypher, humankind,
# Nearest to units: kw, lnot, exponents, redefined, used, variant, islander, realignment,
# Nearest to numerous: pop, moist, mustered, penicillium, louvain, othniel, decry, shintoism,
# Nearest to bbc: notched, visitor, swaziland, overviews, friday, bothnia, creation, pbs,
# Nearest to alternative: laserdisc, twentieth, outlines, hawthorne, clinicians, freeform, bandy, mainstream,
# Nearest to recorded: constantly, piano, probe, memphis, tumultuous, encamped, solidify, delights,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9222 0.4449 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9351 0.4408 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9890 0.4376 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9856 0.4467 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9919 0.4375 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9492 0.4405 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8926 0.4364 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9399 0.4429 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8624 0.4387 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9371 0.4377 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, detract, hampered, archons, lutheranism, disintegrates,
# Nearest to such: sizable, automobile, japanese, bluetooth, icons, primus, entendres, disciplines,
# Nearest to while: prefer, kylix, nonterminal, exchanging, inductors, and, vodun, erstwhile,
# Nearest to he: his, pug, was, priestly, charred, worked, constance, him,
# Nearest to about: composting, cigarette, thessalonians, inland, homology, extends, hotspots, vaginal,
# Nearest to up: arif, clear, bottom, grill, salvius, breezes, revolver, sergius,
# Nearest to an: of, which, the, petrochemical, durians, this, refugee, furigana,
# Nearest to zero: three, two, five, seven, six, four, eight, one,
# Nearest to assembly: legislative, bicameral, executive, unicameral, proportional, appoints, cabinet, elects,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, introducing, grigori,
# Nearest to universe: cosmology, quasars, arabia, lowie, agnostics, existence, inquiry, creationism,
# Nearest to units: kw, lnot, used, exponents, islander, redefined, variant, championship,
# Nearest to numerous: moist, pop, mustered, most, halley, crises, penicillium, decry,
# Nearest to bbc: notched, overviews, visitor, pbs, friday, creation, swaziland, december,
# Nearest to alternative: laserdisc, clinicians, twentieth, outlines, hawthorne, mainstream, freeform, freon,
# Nearest to recorded: memphis, constantly, encamped, probe, sugarcane, piano, isdb, delights,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9311 0.4445 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9382 0.4386 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9381 0.4383 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9779 0.4373 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9717 0.4614 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8952 0.4506 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9525 0.4506 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9558 0.4528 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9304 0.4503 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9219 0.4507 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, leak, detract, emulate, hampered, actinidia,
# Nearest to such: sizable, bluetooth, icons, primus, automobile, entendres, japanese, htp,
# Nearest to while: nonterminal, prefer, kylix, inductors, exchanging, and, rgensen, katal,
# Nearest to he: his, was, pug, worked, him, priestly, charred, paley,
# Nearest to about: thessalonians, composting, cigarette, homology, inland, prez, picture, extends,
# Nearest to up: arif, clear, salvius, bottom, sergius, revolver, wither, dre,
# Nearest to an: of, the, durians, which, this, usair, petrochemical, beatified,
# Nearest to zero: three, two, five, six, seven, eight, one, four,
# Nearest to assembly: legislative, bicameral, unicameral, executive, appoints, elects, cabinet, virginian,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, introducing, academy,
# Nearest to universe: cosmology, quasars, arabia, lowie, creationism, agnostics, inquiry, existence,
# Nearest to units: kw, exponents, lnot, redefined, used, islander, realignment, variant,
# Nearest to numerous: moist, most, mustered, othniel, louvain, pop, shintoism, crises,
# Nearest to bbc: notched, december, overviews, visitor, pbs, friday, day, creation,
# Nearest to alternative: laserdisc, clinicians, hawthorne, freeform, outlines, mainstream, twentieth, exploratory,
# Nearest to recorded: constantly, memphis, piano, encamped, sugarcane, solidify, tumultuous, vh,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9921 0.4602 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9246 0.4535 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9157 0.4502 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9708 0.4485 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9561 0.4489 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9377 0.4494 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9179 0.4541 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9166 0.4505 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9350 0.4364 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9769 0.4368 sec/batch
# Nearest to no: incompatibilities, afforded, approachable, leak, archons, hampered, cleaned, detract,
# Nearest to such: sizable, icons, bluetooth, automobile, entendres, primus, htp, japanese,
# Nearest to while: prefer, nonterminal, kylix, exchanging, inductors, and, true, erstwhile,
# Nearest to he: his, was, pug, worked, him, charred, priestly, urbino,
# Nearest to about: composting, thessalonians, cigarette, inland, global, extends, hotspots, forays,
# Nearest to up: arif, clear, salvius, sergius, escapees, solway, alp, bottom,
# Nearest to an: of, which, the, this, refugee, usair, furigana, petrochemical,
# Nearest to zero: three, five, two, six, seven, four, eight, one,
# Nearest to assembly: bicameral, legislative, executive, unicameral, virginian, cabinet, approved, appoints,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, emmy, introducing,
# Nearest to universe: cosmology, quasars, arabia, lowie, humanoid, inquiry, speculation, cosmological,
# Nearest to units: kw, redefined, lnot, exponents, islander, realignment, championship, used,
# Nearest to numerous: louvain, mustered, most, moist, shintoism, othniel, decry, nonconformists,
# Nearest to bbc: notched, december, overviews, pbs, friday, day, visitor, swaziland,
# Nearest to alternative: laserdisc, clinicians, hawthorne, freon, freeform, outlines, bandy, twentieth,
# Nearest to recorded: probe, constantly, sugarcane, memphis, encamped, country, tumultuous, solidify,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9334 0.4427 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0389 0.4367 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0090 0.4362 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9838 0.4407 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9092 0.4363 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8886 0.4371 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9145 0.4354 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8962 0.4376 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9605 0.4387 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9396 0.4375 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, leak, hampered, detract, actinidia, disintegrates,
# Nearest to such: sizable, icons, automobile, refers, bluetooth, primus, japanese, entendres,
# Nearest to while: nonterminal, prefer, inductors, and, exchanging, kylix, restart, phraseology,
# Nearest to he: his, worked, was, pug, charred, him, priestly, trying,
# Nearest to about: composting, thessalonians, cigarette, inland, vaginal, extends, homology, hotspots,
# Nearest to up: clear, arif, salvius, escapees, alp, revolver, breezes, grill,
# Nearest to an: of, the, which, this, furigana, petrochemical, refugee, durians,
# Nearest to zero: three, two, five, six, seven, eight, four, one,
# Nearest to assembly: legislative, bicameral, unicameral, executive, appoints, approved, proportional, virginian,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, emmy, academy,
# Nearest to universe: quasars, cosmology, lowie, arabia, humanoid, atheos, agnostics, creationism,
# Nearest to units: redefined, kw, exponents, lnot, islander, realignment, used, variant,
# Nearest to numerous: moist, most, othniel, decry, louvain, pop, mustered, penicillium,
# Nearest to bbc: notched, december, overviews, pbs, swaziland, friday, day, visitor,
# Nearest to alternative: laserdisc, hawthorne, clinicians, bandy, twentieth, outlines, mainstream, freeform,
# Nearest to recorded: constantly, sugarcane, memphis, encamped, probe, vh, solidify, piano,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 3.9513 0.4477 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.9262 0.3300 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9159 0.4349 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9153 0.4372 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9392 0.4356 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.8808 0.4366 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.8950 0.4360 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.8251 0.4388 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.9223 0.4383 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9095 0.4368 sec/batch
# Nearest to no: incompatibilities, approachable, archons, afforded, hampered, leak, detract, actinidia,
# Nearest to such: sizable, icons, primus, japanese, automobile, bluetooth, entendres, refers,
# Nearest to while: nonterminal, inductors, prefer, kylix, and, restart, exchanging, rgensen,
# Nearest to he: his, was, worked, charred, him, pug, priestly, moved,
# Nearest to about: composting, thessalonians, cigarette, inland, wroc, extends, vaginal, decss,
# Nearest to up: arif, clear, salvius, crowd, revolver, onshore, stalker, sergius,
# Nearest to an: of, the, which, by, this, petrochemical, refugee, in,
# Nearest to zero: three, two, five, six, seven, eight, four, one,
# Nearest to assembly: legislative, bicameral, unicameral, executive, approved, appoints, proportional, elects,
# Nearest to award: awards, bafta, awarded, best, nominated, academy, oscar, emmy,
# Nearest to universe: quasars, cosmology, arabia, lowie, humanoid, atheos, speculation, cosmological,
# Nearest to units: kw, redefined, exponents, lnot, realignment, islander, normally, championship,
# Nearest to numerous: most, moist, othniel, mustered, shintoism, louvain, decry, penicillium,
# Nearest to bbc: notched, friday, pbs, overviews, december, swaziland, creation, day,
# Nearest to alternative: hawthorne, laserdisc, clinicians, outlines, mainstream, freeform, twentieth, bandy,
# Nearest to recorded: memphis, probe, constantly, sugarcane, encamped, vh, song, solidify,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9146 0.4429 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9337 0.4368 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8084 0.4353 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8773 0.4365 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8557 0.4398 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8375 156.5158 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8874 149.5508 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8852 0.5076 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8598 0.5152 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8751 0.5168 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, leak, detract, archons, disintegrates, unbalanced,
# Nearest to such: sizable, automobile, icons, primus, bluetooth, entendres, htp, increases,
# Nearest to while: nonterminal, prefer, inductors, exchanging, kylix, and, phraseology, rgensen,
# Nearest to he: his, worked, was, charred, him, pug, moved, priestly,
# Nearest to about: composting, thessalonians, cigarette, vaginal, picture, oscillates, inland, paige,
# Nearest to up: clear, arif, salvius, bottom, stalker, dre, revolver, crowd,
# Nearest to an: of, the, by, this, which, furigana, petrochemical, usair,
# Nearest to zero: three, two, five, six, seven, one, eight, four,
# Nearest to assembly: legislative, bicameral, unicameral, executive, appoints, approved, cabinet, virginian,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, won, emmy,
# Nearest to universe: quasars, cosmology, arabia, lowie, humanoid, atheos, cosmological, cosmologists,
# Nearest to units: kw, exponents, redefined, lnot, islander, used, realignment, championship,
# Nearest to numerous: moist, othniel, mustered, most, shintoism, louvain, nonconformists, archiving,
# Nearest to bbc: notched, friday, december, overviews, pbs, day, swaziland, itv,
# Nearest to alternative: hawthorne, clinicians, mainstream, laserdisc, freeform, bandy, outlines, freon,
# Nearest to recorded: encamped, memphis, sugarcane, probe, constantly, song, vh, solidify,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9587 0.4766 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8564 0.4738 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8659 0.5236 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9085 0.5922 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9147 0.5669 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.8843 0.5062 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8931 0.5388 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8997 11.8001 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.8737 0.5206 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9182 0.4652 sec/batch
# Nearest to no: incompatibilities, approachable, archons, tetrarchs, leak, afforded, mok, eaux,
# Nearest to such: sizable, automobile, entendres, icons, bluetooth, increases, primus, polyethylene,
# Nearest to while: prefer, nonterminal, and, phraseology, exchanging, inductors, kylix, azerbaijan,
# Nearest to he: his, worked, was, him, charred, moved, returned, pug,
# Nearest to about: composting, thessalonians, cigarette, extends, jarre, inland, decss, fbi,
# Nearest to up: clear, arif, salvius, escapees, bottom, eon, stalker, crowd,
# Nearest to an: of, the, this, by, which, furigana, for, usair,
# Nearest to zero: three, two, five, six, seven, one, four, eight,
# Nearest to assembly: legislative, bicameral, unicameral, appoints, virginian, executive, approved, proportional,
# Nearest to award: awards, bafta, awarded, best, nominated, oscar, emmy, toscana,
# Nearest to universe: cosmology, quasars, arabia, lowie, humanoid, cosmologists, galactic, cosmological,
# Nearest to units: kw, exponents, lnot, islander, redefined, realignment, sil, used,
# Nearest to numerous: moist, mustered, nonconformists, othniel, louvain, most, genre, shintoism,
# Nearest to bbc: notched, december, pbs, friday, overviews, day, itv, visitor,
# Nearest to alternative: hawthorne, laserdisc, clinicians, freeform, freon, bandy, mainstream, outlines,
# Nearest to recorded: encamped, sugarcane, constantly, probe, memphis, song, vh, bootleg,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.8902 0.4673 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.8967 0.4629 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.8869 0.4495 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8642 0.4501 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9028 0.4611 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9502 0.4500 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8885 0.4811 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9979 0.4564 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.9488 0.4512 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9637 0.4744 sec/batch
# Nearest to no: incompatibilities, approachable, afforded, mok, archons, leak, tetrarchs, sara,
# Nearest to such: sizable, icons, entendres, refers, insults, primus, japanese, automobile,
# Nearest to while: and, prefer, phraseology, expelled, nonterminal, rgensen, exchanging, erstwhile,
# Nearest to he: his, worked, was, charred, received, him, pug, moved,
# Nearest to about: composting, thessalonians, cigarette, vaginal, roussimoff, jarre, fbi, decss,
# Nearest to up: clear, arif, salvius, escapees, stalker, outta, eon, sergius,
# Nearest to an: of, the, by, which, this, refugee, furigana, for,
# Nearest to zero: three, five, two, six, seven, four, one, eight,
# Nearest to assembly: bicameral, legislative, virginian, unicameral, executive, approved, appoints, impeach,
# Nearest to award: awards, bafta, awarded, best, nominated, emmy, oscar, academy,
# Nearest to universe: quasars, cosmology, arabia, humanoid, lowie, atheos, galactic, cosmologists,
# Nearest to units: exponents, redefined, islander, kw, lnot, realignment, sil, normally,
# Nearest to numerous: moist, most, mustered, nonconformists, louvain, othniel, genre, decry,
# Nearest to bbc: notched, december, pbs, friday, day, overviews, itv, swaziland,
# Nearest to alternative: hawthorne, laserdisc, mainstream, clinicians, freeform, bandy, outlines, freon,
# Nearest to recorded: sugarcane, constantly, encamped, memphis, probe, song, bootleg, obligated,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.8843 1.0814 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8510 0.5632 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.8987 0.4716 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8009 0.4580 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9062 0.4582 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.8804 0.4508 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
