# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
# Wow, I started by using a dictionary comprehension, but it took forever...  The sol'n uses a Counter() object
# imported from {collections}.  It take a couple seconds to fully run...
# uniq_words = set(words)
# word_freqs = {word: words.count(word) for word in uniq_words}

from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
min(0,2)
# Out:
# 0

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = random.choice(list(range(1,window_size+1)))
    lower_bound = max(0, idx-R)
    upper_bound = min(idx+R, len(words))  # Should be len(words)+1 s.t. clopen index catches it
    frame = words[lower_bound:idx]+words[idx+1:upper_bound]
    return(frame)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a **generator function** by the way, **helps save memory**.

# %%
# By using a generator function, only one batch need be in memory at any given time.

def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    '''Fill in code'''
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None,None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
# ## Create Embedding Matrix (Weights for Embedding Layer)
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# ## Weights and Biases for Softmax Layer
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6291 0.0695 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5757 0.0710 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4289 0.0696 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5692 0.0686 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4319 0.0681 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4905 0.0678 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5411 0.0679 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5073 0.0680 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3820 0.0693 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3514 0.0697 sec/batch
# Nearest to they: renouf, thalassemia, possessions, mastodon, kaiserliche, wielder, dualism, alans,
# Nearest to are: toxins, calico, maximin, nessie, bub, cartridges, blacksmith, platte,
# Nearest to six: licenced, grievances, tellers, curriculum, hour, hackney, jekyll, pet,
# Nearest to while: patris, duly, rdos, goblet, leventhal, blockade, filipino, nikola,
# Nearest to is: dollywood, lucas, fullwidth, turtledove, ohrid, altenburg, cyberpunk, bandanese,
# Nearest to as: wayne, xxix, eigenvalue, spearhead, mozzarella, tarawa, sideways, rigdon,
# Nearest to three: baptise, plo, ceding, henrik, lorenz, kingfisher, monophyletic, composition,
# Nearest to seven: sibyl, galois, noxious, villeneuve, renfro, credence, freescale, browse,
# Nearest to universe: mayall, popov, holographic, bellamy, columnists, restated, falun, serial,
# Nearest to file: caxton, matriculation, magenta, pull, aleph, edited, ambitions, dyrrhachium,
# Nearest to construction: tippi, resolves, gregorian, empiricism, bem, mme, bouncer, spiritual,
# Nearest to bbc: superhighway, nuclei, loretta, profitable, vindhya, salutation, shankara, recess,
# Nearest to issue: cantonese, rnu, hippias, dictate, embraces, wtro, authored, credits,
# Nearest to bible: deniability, predestined, prussian, vanish, lombard, homer, imitates, reviewer,
# Nearest to existence: sehul, hempstead, casual, ivanov, borrowers, han, kali, toughness,
# Nearest to primarily: nden, ticino, gnosticism, gracen, fujiko, writ, elevation, vat,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4585 0.0707 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3577 0.0693 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3328 0.0698 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2763 0.0697 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1766 0.0688 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1543 0.0695 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1108 0.0691 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0741 0.0694 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0593 0.0696 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0112 0.0692 sec/batch
# Nearest to they: possessions, constraints, renouf, dualism, give, we, wielder, studies,
# Nearest to are: such, advantage, calico, of, toxins, least, satellite, cartridges,
# Nearest to six: licenced, grievances, curriculum, hour, tellers, writings, hackney, facts,
# Nearest to while: blockade, leventhal, duly, rdos, drama, plant, filipino, patris,
# Nearest to is: dollywood, lucas, broad, stable, misinformation, exist, home, fullwidth,
# Nearest to as: wayne, eigenvalue, important, xxix, controllers, rigdon, spearhead, tarawa,
# Nearest to three: baptise, composition, real, plo, lorenz, henrik, clearly, ceding,
# Nearest to seven: galois, sibyl, villeneuve, noxious, expedition, credence, trees, renfro,
# Nearest to universe: mayall, popov, restated, serial, africans, teachings, risks, unusual,
# Nearest to file: edited, pull, aleph, magenta, chipping, caxton, matriculation, samples,
# Nearest to construction: tippi, gregorian, resolves, arrangements, spiritual, empiricism, priority, verse,
# Nearest to bbc: superhighway, nuclei, profitable, loretta, vindhya, beige, modern, contrasts,
# Nearest to issue: cantonese, dictate, pregnancies, credits, corresponding, collectibles, rnu, mexico,
# Nearest to bible: prussian, vanish, ongoing, kind, predestined, homer, rhythm, naps,
# Nearest to existence: casual, sehul, way, hempstead, han, expensive, kali, ivanov,
# Nearest to primarily: nden, gnosticism, vat, ticino, elevation, gracen, writ, fitna,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9267 0.0702 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9213 0.0706 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8954 0.0720 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8685 0.0700 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8097 0.0717 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8475 0.0709 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8082 0.0691 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7770 0.0691 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8156 0.0706 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7832 0.0704 sec/batch
# Nearest to they: possessions, dualism, constraints, renouf, rely, we, wielder, give,
# Nearest to are: such, cartridges, toxins, calico, disapproval, advantage, fabrication, saharan,
# Nearest to six: grievances, licenced, writings, xv, migrant, hour, curriculum, tellers,
# Nearest to while: duly, filipino, patris, blockade, drama, leventhal, rdos, consubstantiation,
# Nearest to is: lucas, dollywood, sixteen, stable, boards, masoretic, misinformation, ohrid,
# Nearest to as: wayne, eigenvalue, porter, xxix, important, spearhead, sideways, controllers,
# Nearest to three: baptise, composition, henrik, ceding, lorenz, real, plo, compact,
# Nearest to seven: galois, villeneuve, sibyl, expedition, renfro, noxious, trees, browse,
# Nearest to universe: mayall, restated, risks, popov, africans, teachings, serial, unusual,
# Nearest to file: pull, edited, aleph, chipping, samples, ambitions, raf, magenta,
# Nearest to construction: tippi, resolves, gregorian, spiritual, bem, empiricism, priority, arrangements,
# Nearest to bbc: superhighway, profitable, nuclei, loretta, speakers, beige, modern, vindhya,
# Nearest to issue: cantonese, dictate, pregnancies, credits, collectibles, corresponding, mexico, authored,
# Nearest to bible: prussian, predestined, homer, ongoing, vanish, rhythm, reviewer, kind,
# Nearest to existence: casual, hempstead, han, sehul, kali, expensive, way, theories,
# Nearest to primarily: vat, gnosticism, nden, ticino, elevation, fitna, writ, gracen,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7877 0.0729 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7583 0.0777 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7191 0.0718 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7514 0.0708 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7298 0.0700 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7068 0.0696 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7019 0.0702 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7181 0.0692 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7402 0.0708 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6702 0.0709 sec/batch
# Nearest to they: dualism, we, constraints, renouf, wielder, rely, neighbor, thalassemia,
# Nearest to are: such, toxins, cartridges, calico, fabrication, nessie, disapproval, saharan,
# Nearest to six: eight, xv, born, licenced, grievances, four, migrant, writings,
# Nearest to while: duly, goblet, patris, rdos, filipino, ticonderoga, millard, dealings,
# Nearest to is: masoretic, dollywood, lucas, stable, misinformation, boards, exist, spiegel,
# Nearest to as: xxix, wayne, porter, sideways, kami, eigenvalue, occult, spearhead,
# Nearest to three: baptise, henrik, lorenz, composition, two, ceding, slit, compact,
# Nearest to seven: galois, villeneuve, renfro, sibyl, expedition, payne, bronte, dramatist,
# Nearest to universe: mayall, restated, popov, africans, serial, bailiff, bellamy, risks,
# Nearest to file: pull, caxton, raf, aleph, samples, chipping, magenta, edited,
# Nearest to construction: tippi, resolves, spiritual, bem, empiricism, gregorian, mme, devices,
# Nearest to bbc: superhighway, profitable, nuclei, beige, loretta, vindhya, broadcast, hearn,
# Nearest to issue: dictate, cantonese, pregnancies, embraces, credits, collectibles, regarding, district,
# Nearest to bible: predestined, homer, prussian, lombard, ongoing, birch, rhythm, reviewer,
# Nearest to existence: casual, hempstead, kali, sehul, way, han, theories, ivanov,
# Nearest to primarily: ticino, gnosticism, vat, nden, writ, elevation, opiate, gracen,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6905 0.0709 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6542 0.0713 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6229 0.0700 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6355 0.0702 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6586 0.0698 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6390 0.0700 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6298 0.0495 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5522 0.0687 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5222 0.0692 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5167 0.0706 sec/batch
# Nearest to they: dualism, we, constraints, predication, segregate, tley, describing, possessions,
# Nearest to are: such, toxins, cartridges, calico, advantage, maximin, nessie, saharan,
# Nearest to six: four, eight, born, migrant, d, licenced, johannes, scholar,
# Nearest to while: ticonderoga, patris, nikola, duly, dish, eras, dealings, consubstantiation,
# Nearest to is: masoretic, mongolians, exist, infested, stable, spiegel, load, dollywood,
# Nearest to as: xxix, sideways, spearhead, kami, occult, porter, tarawa, wayne,
# Nearest to three: baptise, two, henrik, ceding, nine, lorenz, slit, mandela,
# Nearest to seven: villeneuve, galois, renfro, dramatist, thomas, rican, statesman, payne,
# Nearest to universe: mayall, restated, serial, bailiff, mishnah, africans, clitoris, risks,
# Nearest to file: pull, samples, caxton, abstract, raf, rosetta, aleph, chipping,
# Nearest to construction: tippi, resolves, mme, empiricism, wage, bouncer, paratroopers, bem,
# Nearest to bbc: superhighway, profitable, hearn, broadcast, beige, loretta, vindhya, salutation,
# Nearest to issue: dictate, cantonese, pregnancies, embraces, regarding, collectibles, credits, alumnus,
# Nearest to bible: predestined, homer, mite, prussian, lombard, deniability, birch, reviewer,
# Nearest to existence: casual, kali, hempstead, theories, way, anthropic, sehul, respect,
# Nearest to primarily: ticino, vat, nden, opiate, gnosticism, writ, humanities, elevation,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5133 0.0715 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5038 0.0723 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4556 0.0713 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5353 0.0720 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4828 0.0721 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4732 0.0716 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4807 0.0695 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4177 0.0699 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4384 0.0698 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4188 0.0718 sec/batch
# Nearest to they: dualism, we, predication, tley, neighbor, constraints, rely, describing,
# Nearest to are: such, toxins, cartridges, calico, advantage, fabrication, of, capacities,
# Nearest to six: four, xv, eight, licenced, migrant, petitioned, census, zero,
# Nearest to while: eras, dish, dealings, consubstantiation, patris, rdos, ticonderoga, goblet,
# Nearest to is: masoretic, exist, stable, distinguish, spiegel, here, solve, sterilisation,
# Nearest to as: sideways, spearhead, occult, tarawa, wayne, kami, organometallic, wraith,
# Nearest to three: two, baptise, henrik, five, ceding, lorenz, slit, decca,
# Nearest to seven: villeneuve, sibyl, renfro, galois, rican, initiator, payne, guilder,
# Nearest to universe: mayall, restated, serial, elegans, teachings, clitoris, mishnah, africans,
# Nearest to file: samples, abstract, pull, caxton, raf, chipping, discs, aleph,
# Nearest to construction: tippi, resolves, wage, paratroopers, mme, bouncer, empiricism, gregorian,
# Nearest to bbc: superhighway, broadcast, profitable, hearn, dystopic, beige, vindhya, chimes,
# Nearest to issue: dictate, cantonese, pregnancies, hippias, embraces, hoped, repainted, alumnus,
# Nearest to bible: predestined, homer, mite, imitates, lombard, prussian, books, birch,
# Nearest to existence: casual, kali, hempstead, theories, way, respect, psychological, irrational,
# Nearest to primarily: ticino, vat, nden, opiate, gnosticism, thai, humanities, elevation,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4637 0.0732 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3845 0.0702 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4337 0.0705 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3772 0.0714 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4105 0.0708 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4225 0.0702 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3793 0.0707 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3685 0.0709 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3956 0.0723 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3738 0.0714 sec/batch
# Nearest to they: dualism, we, predication, possessions, neighbor, tley, wielder, segregate,
# Nearest to are: such, toxins, calico, cartridges, fabrication, capacities, least, perceptible,
# Nearest to six: four, eight, zero, two, primeval, census, petitioned, migrant,
# Nearest to while: dish, patris, chronic, ticonderoga, consubstantiation, rdos, transcribing, eras,
# Nearest to is: masoretic, exist, emphasizes, here, infested, probabilities, mongolians, sterilisation,
# Nearest to as: sideways, tarawa, important, occult, rembrandt, xxix, spearhead, wraith,
# Nearest to three: two, five, four, baptise, nine, slit, henrik, lorenz,
# Nearest to seven: sibyl, renfro, villeneuve, thomas, galois, rican, dramatist, initiator,
# Nearest to universe: mayall, restated, clitoris, elegans, measurements, poiseuille, serial, pentecostals,
# Nearest to file: abstract, samples, pull, caxton, discs, shareware, chipping, giantesses,
# Nearest to construction: tippi, paratroopers, resolves, wage, mme, spark, deforestation, bouncer,
# Nearest to bbc: superhighway, broadcast, profitable, dystopic, hearn, beige, cyclopaedia, vindhya,
# Nearest to issue: dictate, hippias, cantonese, pregnancies, embraces, litigation, credits, alumnus,
# Nearest to bible: predestined, homer, books, authenticity, mite, imitates, translated, lombard,
# Nearest to existence: theories, hempstead, casual, kali, way, psychological, respect, anthropic,
# Nearest to primarily: ticino, vat, opiate, thai, nden, elevation, practicable, gnosticism,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3630 0.0711 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3874 0.0696 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3311 0.0693 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3699 0.0692 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4085 0.0699 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3865 0.0693 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3593 0.0714 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3907 0.0720 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3156 0.0765 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3127 0.0750 sec/batch
# Nearest to they: dualism, predication, segregate, we, tley, possessions, wielder, constraints,
# Nearest to are: such, toxins, calico, perceptible, fabrication, capacities, cumin, pronounced,
# Nearest to six: four, zero, eight, two, three, primeval, migrant, petitioned,
# Nearest to while: patris, ticonderoga, transcribing, chronic, consubstantiation, dealings, goblet, thro,
# Nearest to is: masoretic, firework, exist, infested, twinned, here, inadvertent, probabilities,
# Nearest to as: important, rembrandt, idolatrous, tarawa, occult, wraith, calculations, xxix,
# Nearest to three: two, five, four, nine, six, zero, composition, lorenz,
# Nearest to seven: sibyl, renfro, galois, villeneuve, thomas, rican, nine, bretwalda,
# Nearest to universe: mayall, restated, poiseuille, measurements, elegans, iterating, repetition, clitoris,
# Nearest to file: abstract, samples, shareware, caxton, discs, pull, giantesses, chipping,
# Nearest to construction: tippi, wage, paratroopers, mme, resolves, deforestation, bouncer, middlemen,
# Nearest to bbc: superhighway, broadcast, profitable, hearn, beige, chimes, encyclopaedia, dystopic,
# Nearest to issue: dictate, regarding, credits, hippias, embraces, litigation, pregnancies, candidates,
# Nearest to bible: predestined, tanakh, homer, translated, authenticity, imitates, books, lds,
# Nearest to existence: theories, kali, hempstead, casual, anthropic, way, irrational, itself,
# Nearest to primarily: ticino, vat, opiate, thai, gnosticism, elevation, nden, fitna,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3410 0.0711 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2895 0.0694 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3608 0.0700 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3734 0.0697 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3635 0.0701 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2661 0.0722 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3046 0.0710 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3193 0.0691 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1915 0.0701 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2650 0.0698 sec/batch
# Nearest to they: dualism, predication, tley, we, possessions, divide, neighbor, segregate,
# Nearest to are: such, toxins, calico, perceptible, capacities, cumin, least, hedging,
# Nearest to six: four, zero, eight, two, three, migrant, erich, est,
# Nearest to while: patris, ticonderoga, chronic, transcribing, uqqal, thro, dealings, goblet,
# Nearest to is: masoretic, firework, exist, distinguish, numerator, infested, twinned, here,
# Nearest to as: xxix, idolatrous, wraith, rembrandt, occult, important, tarawa, spearhead,
# Nearest to three: two, five, four, nine, zero, six, one, henrik,
# Nearest to seven: nine, eight, villeneuve, renfro, zero, thomas, sibyl, galois,
# Nearest to universe: mayall, restated, poiseuille, clitoris, iterating, measurements, elegans, mishnah,
# Nearest to file: abstract, shareware, samples, files, discs, caxton, macintosh, protocols,
# Nearest to construction: tippi, wage, mme, paratroopers, resolves, deforestation, spark, superclasses,
# Nearest to bbc: broadcast, superhighway, encyclopaedia, isaak, hearn, beige, profitable, chimes,
# Nearest to issue: dictate, regarding, hippias, credits, dvd, pregnancies, embraces, litigation,
# Nearest to bible: tanakh, predestined, homer, lombard, lds, authenticity, mite, translated,
# Nearest to existence: theories, kali, hempstead, anthropic, way, casual, itself, irrational,
# Nearest to primarily: ticino, opiate, thai, vat, imports, elevation, humanities, practicable,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3109 0.0704 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2853 0.0705 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3108 0.0298 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2240 0.0712 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1854 0.0705 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1938 0.0710 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1773 0.0720 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2102 0.0691 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2065 0.0688 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1644 0.0698 sec/batch
# Nearest to they: possessions, dualism, tley, predication, neighbor, segregate, rely, wielder,
# Nearest to are: such, toxins, calico, hedging, perceptible, cumin, fabrication, origin,
# Nearest to six: four, zero, two, eight, three, migrant, one, est,
# Nearest to while: thro, dish, patris, transcribing, chronic, often, consubstantiation, ticonderoga,
# Nearest to is: masoretic, firework, coasts, numerator, matador, inadvertent, forwards, exist,
# Nearest to as: wraith, important, tarawa, xxix, rembrandt, occult, idolatrous, the,
# Nearest to three: two, four, five, six, nine, one, zero, henrik,
# Nearest to seven: sibyl, guilder, villeneuve, eight, nine, renfro, zero, thomas,
# Nearest to universe: mayall, restated, poiseuille, clitoris, cleverness, iterating, measurements, interventional,
# Nearest to file: abstract, shareware, files, rosetta, caxton, discs, samples, macintosh,
# Nearest to construction: tippi, paratroopers, wage, mme, deforestation, residential, mauser, resolves,
# Nearest to bbc: broadcast, superhighway, encyclopaedia, hearn, beige, isaak, profitable, xylophone,
# Nearest to issue: dictate, regarding, hippias, credits, litigation, dvd, pregnancies, sirius,
# Nearest to bible: tanakh, books, authenticity, predestined, lombard, translated, lds, imitates,
# Nearest to existence: theories, kali, anthropic, hempstead, irrational, personalized, casual, itself,
# Nearest to primarily: ticino, thai, imports, vat, opiate, practicable, fitna, gnosticism,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2278 0.0718 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1998 0.0721 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2099 0.0700 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1446 0.0711 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1606 0.0715 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1393 0.0703 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1561 0.0713 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1455 0.0715 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1772 0.0700 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1292 0.0693 sec/batch
# Nearest to they: dualism, possessions, predication, tley, neighbor, we, paddington, divide,
# Nearest to are: such, toxins, calico, edges, cumin, least, hedging, perceptible,
# Nearest to six: four, zero, two, three, eight, migrant, five, primeval,
# Nearest to while: consubstantiation, patris, thro, transcribing, chronic, dish, ticonderoga, uqqal,
# Nearest to is: masoretic, firework, numerator, inadvertent, spiegel, here, vector, or,
# Nearest to as: occult, important, the, wraith, tarawa, xxix, rembrandt, sideways,
# Nearest to three: two, five, four, six, one, nine, zero, m,
# Nearest to seven: zero, renfro, sibyl, guilder, km, nine, eight, villeneuve,
# Nearest to universe: mayall, restated, poiseuille, measurements, iterating, cleverness, elegans, countably,
# Nearest to file: files, abstract, shareware, rosetta, caxton, discs, samples, macintosh,
# Nearest to construction: paratroopers, tippi, wage, mme, residential, deforestation, resolves, mauser,
# Nearest to bbc: broadcast, superhighway, beige, encyclopaedia, chimes, profitable, isaak, vindhya,
# Nearest to issue: dictate, regarding, hippias, dvd, embraces, sirius, pregnancies, candidates,
# Nearest to bible: tanakh, books, predestined, authenticity, lds, mechon, masoretic, judith,
# Nearest to existence: anthropic, theories, kali, hempstead, irrational, personalized, way, inconsistent,
# Nearest to primarily: ticino, thai, imports, vat, opiate, practicable, arabized, schistosomiasis,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1241 0.0713 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2208 0.0691 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1437 0.0722 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1541 0.0708 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1420 0.0707 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1735 0.0709 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1665 0.0701 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1436 0.0710 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1179 0.0715 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1614 0.0704 sec/batch
# Nearest to they: dualism, neighbor, predication, possessions, we, tley, paddington, rely,
# Nearest to are: such, edges, calico, perceptible, cumin, toxins, hedging, fabrication,
# Nearest to six: four, zero, two, three, eight, five, one, migrant,
# Nearest to while: patris, thro, uqqal, transcribing, consubstantiation, ticonderoga, often, chronic,
# Nearest to is: masoretic, firework, inadvertent, spiegel, numerator, or, mujahid, vectors,
# Nearest to as: occult, wraith, important, the, tarawa, xxix, rembrandt, typological,
# Nearest to three: two, four, five, one, nine, six, zero, eight,
# Nearest to seven: nine, eight, zero, thomas, renfro, sibyl, one, two,
# Nearest to universe: poiseuille, mayall, restated, measurements, iterating, cleverness, kaluza, repetition,
# Nearest to file: files, abstract, shareware, rosetta, caxton, discs, psych, giantesses,
# Nearest to construction: paratroopers, tippi, wage, mme, residential, deforestation, resolves, middlemen,
# Nearest to bbc: broadcast, superhighway, encyclopaedia, beige, cyclopaedia, profitable, mirth, plotinus,
# Nearest to issue: regarding, dictate, dvd, candidates, litigation, hippias, credits, sirius,
# Nearest to bible: tanakh, books, mechon, predestined, lds, masoretic, judith, authenticity,
# Nearest to existence: theories, anthropic, kali, hempstead, irrational, personalized, itself, way,
# Nearest to primarily: ticino, thai, opiate, vat, fitna, gnosticism, arabized, schistosomiasis,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1759 0.0715 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1551 0.0753 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1616 0.0822 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1743 0.0743 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1183 0.0724 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1144 0.0706 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1429 0.0701 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1268 0.0714 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1715 0.0720 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2006 0.0694 sec/batch
# Nearest to they: possessions, dualism, neighbor, predication, we, paddington, tley, serrated,
# Nearest to are: such, hedging, representing, edges, calico, perceptible, cumin, origin,
# Nearest to six: four, zero, two, eight, three, one, five, migrant,
# Nearest to while: patris, thro, uqqal, ticonderoga, consubstantiation, often, goblet, critic,
# Nearest to is: firework, masoretic, inadvertent, or, mujahid, spiegel, distinguish, exist,
# Nearest to as: the, xxix, important, occult, rembrandt, wayne, typological, wraith,
# Nearest to three: two, five, four, nine, one, six, zero, eight,
# Nearest to seven: nine, zero, one, eight, thomas, two, renfro, six,
# Nearest to universe: poiseuille, mayall, measurements, restated, cleverness, iterating, kaluza, teachings,
# Nearest to file: files, abstract, shareware, rosetta, caxton, psych, timex, samples,
# Nearest to construction: paratroopers, tippi, mme, wage, residential, ivy, resolves, deforestation,
# Nearest to bbc: broadcast, superhighway, events, encyclopaedia, external, beige, mirth, cyclopaedia,
# Nearest to issue: regarding, dictate, dvd, liberalised, litigation, frustrations, hippias, fraternal,
# Nearest to bible: tanakh, mechon, predestined, books, masoretic, imitates, lds, authenticity,
# Nearest to existence: anthropic, theories, kali, hempstead, personalized, itself, way, momentous,
# Nearest to primarily: ticino, thai, opiate, fitna, arabized, vat, gnosticism, practicable,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1989 0.0704 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1133 0.0688 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1058 0.0704 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1127 0.0699 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0310 0.0694 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1168 0.0699 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1306 0.0691 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1068 0.0691 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1394 0.0096 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1151 0.0708 sec/batch
# Nearest to they: possessions, neighbor, dualism, paddington, serrated, predication, we, tley,
# Nearest to are: such, calico, hedging, edges, toxins, cumin, fabrication, ebay,
# Nearest to six: four, zero, two, three, eight, five, one, migrant,
# Nearest to while: often, thro, patris, kahanism, uqqal, chronic, quirin, goblet,
# Nearest to is: firework, masoretic, inadvertent, or, numerator, neighbouring, twinned, a,
# Nearest to as: the, wraith, important, rembrandt, occult, typological, xxix, tarawa,
# Nearest to three: two, four, five, nine, one, zero, six, eight,
# Nearest to seven: zero, nine, eight, one, two, thomas, renfro, five,
# Nearest to universe: poiseuille, measurements, cleverness, mayall, restated, iterating, kaluza, interventional,
# Nearest to file: files, shareware, abstract, rosetta, commands, caxton, discs, timex,
# Nearest to construction: paratroopers, mme, residential, wage, tippi, revolving, mauser, deforestation,
# Nearest to bbc: broadcast, superhighway, events, encyclopaedia, external, news, beige, listing,
# Nearest to issue: regarding, dvd, dictate, fraternal, liberalised, frustrations, newspaper, authored,
# Nearest to bible: tanakh, mechon, predestined, masoretic, lds, imitates, mite, authenticity,
# Nearest to existence: anthropic, theories, kali, personalized, hempstead, way, itself, momentous,
# Nearest to primarily: ticino, thai, opiate, arabized, fitna, vat, imports, practicable,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0494 0.0704 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0463 0.0693 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0659 0.0694 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0385 0.0696 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0342 0.0724 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0311 0.0721 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0482 0.0712 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0757 0.0710 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0696 0.0702 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0124 0.0709 sec/batch
# Nearest to they: paddington, neighbor, dualism, possessions, we, serrated, bereft, predication,
# Nearest to are: such, of, edges, cumin, toxins, calico, hedging, ebay,
# Nearest to six: four, zero, three, two, eight, five, one, migrant,
# Nearest to while: thro, often, uqqal, transcribing, kahanism, encircled, quirin, slr,
# Nearest to is: or, inadvertent, firework, a, masoretic, tablature, common, numerator,
# Nearest to as: the, occult, wraith, typological, important, abrogation, tarawa, rembrandt,
# Nearest to three: two, four, five, one, nine, six, zero, eight,
# Nearest to seven: zero, nine, one, eight, two, four, three, guilder,
# Nearest to universe: measurements, poiseuille, cleverness, mayall, restated, iterating, kaluza, helium,
# Nearest to file: files, abstract, shareware, rosetta, commands, caxton, giantesses, timex,
# Nearest to construction: paratroopers, wage, residential, mme, tippi, resolves, mauser, deforestation,
# Nearest to bbc: broadcast, external, encyclopaedia, news, superhighway, events, televisions, mirth,
# Nearest to issue: dictate, regarding, newspaper, dvd, fraternal, sirius, liberalised, hippias,
# Nearest to bible: tanakh, mechon, books, masoretic, lds, predestined, authenticity, judith,
# Nearest to existence: kali, anthropic, theories, personalized, hempstead, way, bloom, momentous,
# Nearest to primarily: ticino, thai, opiate, arabized, fitna, imports, practicable, vat,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0266 0.0721 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9953 0.0707 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9570 0.0711 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9871 0.0712 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0316 0.0721 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0253 0.0722 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0154 0.0734 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0655 0.0704 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0173 0.0707 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9631 0.0696 sec/batch
# Nearest to they: neighbor, dualism, we, paddington, possessions, serrated, predication, bereft,
# Nearest to are: such, cumin, of, applies, edges, calico, hedging, fabrication,
# Nearest to six: four, zero, two, three, eight, five, one, migrant,
# Nearest to while: thro, uqqal, often, transcribing, quirin, trespass, kahanism, chronic,
# Nearest to is: a, or, inadvertent, firework, masoretic, tablature, scorch, numerator,
# Nearest to as: the, occult, important, typological, wraith, tarawa, wayne, rembrandt,
# Nearest to three: two, four, five, one, nine, six, zero, eight,
# Nearest to seven: zero, nine, one, eight, two, three, four, six,
# Nearest to universe: poiseuille, measurements, cleverness, mayall, restated, occultist, helium, iterating,
# Nearest to file: files, abstract, rosetta, shareware, caxton, samples, commands, documents,
# Nearest to construction: residential, wage, mme, paratroopers, tippi, lalr, resolves, dependable,
# Nearest to bbc: broadcast, encyclopaedia, news, external, events, superhighway, viewers, listing,
# Nearest to issue: dictate, regarding, dvd, sirius, frustrations, newspaper, fraternal, experiential,
# Nearest to bible: tanakh, mechon, masoretic, books, lds, predestined, judith, imitates,
# Nearest to existence: kali, anthropic, theories, hempstead, personalized, way, momentous, bloom,
# Nearest to primarily: ticino, thai, arabized, opiate, fitna, practicable, vat, schistosomiasis,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0091 0.0722 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0282 0.0753 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0505 0.0737 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0277 0.0716 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0356 0.0705 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0088 0.0712 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0439 0.0712 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0595 0.0723 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0550 0.0715 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0229 0.0705 sec/batch
# Nearest to they: we, neighbor, dualism, paddington, predication, serrated, bereft, describing,
# Nearest to are: such, edges, cumin, calico, applies, hedging, origin, fabrication,
# Nearest to six: four, zero, two, three, eight, five, one, seven,
# Nearest to while: thro, quirin, uqqal, transcribing, often, patris, kahanism, ticonderoga,
# Nearest to is: a, or, inadvertent, firework, masoretic, scorch, vector, isomorphic,
# Nearest to as: the, occult, typological, rembrandt, important, wraith, abrogation, improbable,
# Nearest to three: two, five, four, nine, one, six, zero, eight,
# Nearest to seven: zero, nine, one, eight, two, three, six, four,
# Nearest to universe: poiseuille, measurements, cleverness, restated, galaxies, helium, mayall, novels,
# Nearest to file: files, abstract, rosetta, shareware, caxton, samples, codenamed, giantesses,
# Nearest to construction: residential, mme, wage, paratroopers, tippi, revolving, lalr, ivy,
# Nearest to bbc: broadcast, encyclopaedia, news, events, external, mirth, viewers, superhighway,
# Nearest to issue: regarding, dictate, frustrations, fraternal, liberalised, dvd, newspaper, priority,
# Nearest to bible: tanakh, mechon, masoretic, predestined, books, imitates, lds, mite,
# Nearest to existence: kali, anthropic, theories, personalized, hempstead, way, momentous, elliptical,
# Nearest to primarily: ticino, thai, arabized, fitna, opiate, vat, practicable, rigorously,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0069 0.0715 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9965 0.0708 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9989 0.0712 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0670 0.0717 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.9923 0.0708 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0846 0.0716 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0956 0.0707 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0073 0.0716 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9814 0.0695 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0149 0.0699 sec/batch
# Nearest to they: we, serrated, neighbor, bereft, paddington, predication, dualism, infraction,
# Nearest to are: such, hedging, calico, other, ebay, cumin, fabrication, edges,
# Nearest to six: four, zero, two, three, five, eight, one, seven,
# Nearest to while: thro, uqqal, quirin, sloop, often, patris, idolized, ticonderoga,
# Nearest to is: or, firework, a, inadvertent, masoretic, scorch, numerator, and,
# Nearest to as: the, occult, important, wraith, typological, xxix, papiamento, rembrandt,
# Nearest to three: two, five, four, nine, one, six, zero, eight,
# Nearest to seven: zero, one, nine, two, eight, four, three, six,
# Nearest to universe: poiseuille, cleverness, measurements, restated, galaxies, occultist, mayall, kaluza,
# Nearest to file: files, abstract, rosetta, caxton, caprino, ldap, commands, shareware,
# Nearest to construction: mme, paratroopers, wage, residential, tippi, revolving, lalr, tighten,
# Nearest to bbc: broadcast, news, external, events, encyclopaedia, listing, february, viewers,
# Nearest to issue: regarding, dictate, dvd, frustrations, fraternal, newspaper, sirius, candidates,
# Nearest to bible: tanakh, mechon, masoretic, books, imitates, predestined, hasmonaean, mite,
# Nearest to existence: kali, anthropic, theories, personalized, way, hempstead, momentous, elliptical,
# Nearest to primarily: ticino, thai, arabized, fitna, opiate, practicable, gnosticism, rigorously,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9425 0.0713 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9657 0.0711 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9950 0.0708 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9756 0.0710 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0437 0.0725 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0044 0.0616 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9659 0.0722 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9472 0.0716 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9633 0.0696 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9519 0.0701 sec/batch
# Nearest to they: we, serrated, paddington, bereft, predication, infraction, neighbor, dualism,
# Nearest to are: such, calico, cumin, hedging, other, of, skulls, okina,
# Nearest to six: four, zero, two, three, one, eight, five, seven,
# Nearest to while: quirin, thro, often, uqqal, kahanism, encircled, patris, simple,
# Nearest to is: a, firework, or, inadvertent, masoretic, with, tablature, sectioned,
# Nearest to as: the, wraith, occult, important, typological, papiamento, improbable, xxix,
# Nearest to three: two, four, five, one, nine, six, zero, eight,
# Nearest to seven: one, zero, nine, two, eight, four, three, six,
# Nearest to universe: poiseuille, cleverness, measurements, occultist, restated, novels, mayall, tilted,
# Nearest to file: files, rosetta, abstract, caxton, shareware, samples, commands, ldap,
# Nearest to construction: mme, paratroopers, residential, wage, tippi, revolving, tuileries, kitakyushu,
# Nearest to bbc: external, news, listing, events, broadcast, encyclopaedia, february, january,
# Nearest to issue: regarding, dvd, newspaper, frustrations, dictate, fraternal, candidates, sirius,
# Nearest to bible: mechon, tanakh, masoretic, hasmonaean, predestined, imitates, books, domino,
# Nearest to existence: kali, anthropic, theories, personalized, way, elliptical, ontological, hempstead,
# Nearest to primarily: ticino, thai, arabized, fitna, rigorously, opiate, gradients, practicable,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9517 0.0728 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9111 0.0720 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9991 0.0702 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0035 0.0705 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9963 0.0715 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9664 0.0721 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8680 0.0729 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9617 0.0708 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8710 0.0771 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9020 0.0721 sec/batch
# Nearest to they: we, bereft, predication, paddington, serrated, neighbor, dualism, turnovers,
# Nearest to are: such, of, other, calico, cumin, edges, some, number,
# Nearest to six: four, zero, two, five, three, eight, one, seven,
# Nearest to while: uqqal, quirin, sloop, kahanism, thro, encircled, simple, slr,
# Nearest to is: a, or, inadvertent, firework, finite, masoretic, the, particular,
# Nearest to as: the, wraith, occult, important, papiamento, improbable, wayne, typological,
# Nearest to three: two, five, four, one, nine, six, zero, eight,
# Nearest to seven: zero, one, nine, two, four, three, six, eight,
# Nearest to universe: measurements, poiseuille, galaxies, cleverness, restated, kaluza, tilted, occultist,
# Nearest to file: files, abstract, rosetta, commands, samples, caxton, shareware, caprino,
# Nearest to construction: paratroopers, residential, mme, wage, tippi, revolving, spiritual, tighten,
# Nearest to bbc: news, external, encyclopaedia, broadcast, listing, viewers, events, february,
# Nearest to issue: regarding, dvd, dictate, newspaper, frustrations, candidates, sirius, maelstrom,
# Nearest to bible: tanakh, mechon, masoretic, books, hasmonaean, predestined, abridged, imitates,
# Nearest to existence: kali, anthropic, theories, personalized, way, elliptical, ontological, bloom,
# Nearest to primarily: ticino, thai, arabized, fitna, rigorously, gradients, practicable, pure,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9272 0.0730 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9676 0.0708 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9315 0.0723 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9782 0.0716 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0188 0.0705 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9098 0.0702 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9242 0.0711 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9621 0.0701 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9464 0.0710 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9221 0.0695 sec/batch
# Nearest to they: we, predication, paddington, neighbor, bereft, cherry, serrated, picking,
# Nearest to are: such, other, of, rykodisc, calico, applies, number, ebay,
# Nearest to six: four, zero, two, three, five, eight, one, nine,
# Nearest to while: uqqal, sloop, kahanism, thro, quirin, ticonderoga, slr, batters,
# Nearest to is: a, or, inadvertent, the, with, firework, finite, particular,
# Nearest to as: the, occult, improbable, wraith, wayne, important, amano, by,
# Nearest to three: two, five, four, one, nine, six, zero, eight,
# Nearest to seven: one, nine, zero, two, eight, four, six, three,
# Nearest to universe: poiseuille, measurements, galaxies, novels, cleverness, tilted, restated, mayall,
# Nearest to file: files, abstract, rosetta, commands, samples, giantesses, caxton, documents,
# Nearest to construction: residential, wage, paratroopers, mme, tippi, revolving, tighten, tuileries,
# Nearest to bbc: news, external, listing, encyclopaedia, february, viewers, events, broadcast,
# Nearest to issue: regarding, dictate, frustrations, candidates, dvd, newspaper, fraternal, maelstrom,
# Nearest to bible: tanakh, mechon, masoretic, books, hasmonaean, predestined, lds, abridged,
# Nearest to existence: kali, anthropic, theories, personalized, way, elliptical, ontological, bloom,
# Nearest to primarily: ticino, arabized, thai, fitna, rigorously, gradients, practicable, valeria,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9664 0.0707 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9625 0.0705 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9414 0.0699 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9640 0.0696 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9670 0.0700 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9608 0.0708 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9514 0.0708 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9147 0.0697 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9051 0.0708 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9564 0.0715 sec/batch
# Nearest to they: we, predication, serrated, cherry, overcharged, bereft, paddington, describing,
# Nearest to are: such, other, of, number, some, calico, hedging, homomorphisms,
# Nearest to six: four, zero, two, three, five, eight, one, seven,
# Nearest to while: uqqal, thro, sloop, encircled, ticonderoga, kahanism, quirin, this,
# Nearest to is: a, or, the, inadvertent, with, in, and, firework,
# Nearest to as: the, occult, improbable, important, of, typological, papiamento, by,
# Nearest to three: two, five, four, one, nine, six, zero, eight,
# Nearest to seven: one, zero, nine, four, two, six, eight, three,
# Nearest to universe: galaxies, poiseuille, measurements, cleverness, tilted, novels, restated, occultist,
# Nearest to file: files, abstract, rosetta, samples, giantesses, caprino, codec, commands,
# Nearest to construction: wage, tippi, residential, revolving, mme, paratroopers, tighten, tunnels,
# Nearest to bbc: external, encyclopaedia, news, viewers, events, listing, february, january,
# Nearest to issue: regarding, candidates, frustrations, dictate, dvd, newspaper, priority, sirius,
# Nearest to bible: tanakh, mechon, masoretic, hasmonaean, books, predestined, imitates, scum,
# Nearest to existence: kali, anthropic, theories, personalized, way, elliptical, bloom, dolchsto,
# Nearest to primarily: ticino, arabized, thai, fitna, rigorously, gradients, valeria, gnosticism,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9665 0.0723 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0632 0.0724 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9709 0.0707 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0073 0.0698 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9057 0.0693 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8946 0.0698 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9416 0.0699 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8671 0.0700 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9370 0.0724 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9015 0.0716 sec/batch
# Nearest to they: we, serrated, cherry, paddington, bereft, excite, people, predication,
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8260 0.0724 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.6967 0.0707 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7936 0.0698 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7336 0.0694 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7222 0.0698 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7887 0.0694 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8096 0.0689 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7733 0.0695 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7800 0.0692 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8692 0.0705 sec/batch
# Nearest to they: them, teens, bereft, people, abandon, maynard, cherry, but,
# Nearest to are: such, other, those, of, all, or, these, for,
# Nearest to six: four, five, two, zero, three, one, eight, nine,
# Nearest to while: which, as, an, endothelial, in, and, instead, this,
# Nearest to is: a, the, in, an, or, and, with, be,
# Nearest to as: the, and, of, by, for, a, which, in,
# Nearest to three: two, five, one, four, nine, six, zero, eight,
# Nearest to seven: one, nine, zero, two, five, six, four, eight,
# Nearest to universe: wormhole, pillars, galaxies, novels, tilted, restated, helium, africans,
# Nearest to file: files, abstract, samples, giantesses, sinks, zealand, spaniel, compress,
# Nearest to construction: lalr, tighten, tunnels, intrusions, revolving, building, tippi, dam,
# Nearest to bbc: external, february, december, january, news, viewers, encyclopaedia, listing,
# Nearest to issue: frustrations, regarding, priority, tariff, djvu, pervasive, sideways, investor,
# Nearest to bible: mechon, tanakh, lasor, masoretic, hasmonaean, haggai, trademarked, judith,
# Nearest to existence: anthropic, ontological, kali, bombers, moldova, theories, that, momentous,
# Nearest to primarily: fitna, mikado, ticino, arabized, rigorously, supplying, gnosticism, husks,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7747 0.0739 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7953 0.0701 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7895 0.0693 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7797 0.0693 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8036 0.0696 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8124 0.0695 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7877 0.0693 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7771 0.0721 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8222 0.0754 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8260 0.0722 sec/batch
# Nearest to they: them, teens, abandon, people, maynard, bereft, kaiserliche, specialized,
# Nearest to are: such, other, those, all, of, these, or, each,
# Nearest to six: four, five, two, zero, three, one, eight, nine,
# Nearest to while: which, an, as, endothelial, this, instead, able, to,
# Nearest to is: a, the, in, or, an, and, with, this,
# Nearest to as: the, of, and, which, by, also, for, a,
# Nearest to three: two, one, five, four, nine, six, zero, eight,
# Nearest to seven: one, nine, zero, four, two, six, eight, five,
# Nearest to universe: pillars, galaxies, wormhole, novels, tilted, restated, wormholes, helium,
# Nearest to file: files, abstract, format, coder, zealand, compress, giantesses, sinks,
# Nearest to construction: lalr, tunnels, intrusions, tighten, revolving, building, tippi, dam,
# Nearest to bbc: external, february, news, december, january, encyclopaedia, viewers, woe,
# Nearest to issue: frustrations, priority, djvu, tariff, regarding, pervasive, investor, hoped,
# Nearest to bible: lasor, tanakh, mechon, hasmonaean, masoretic, haggai, trademarked, nebuchadnezzar,
# Nearest to existence: bombers, ontological, anthropic, moldova, kali, theories, proper, that,
# Nearest to primarily: fitna, mikado, rigorously, gnosticism, ticino, arabized, supplying, valeria,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7819 0.0725 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7939 0.0694 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7769 0.0693 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7677 0.0699 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8069 0.0696 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8170 0.0696 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.8912 0.0707 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8506 0.0706 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8600 0.0696 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7825 0.0701 sec/batch
# Nearest to they: them, teens, bereft, abandon, people, maynard, leto, that,
# Nearest to are: such, other, those, of, for, these, all, or,
# Nearest to six: four, five, two, zero, three, eight, nine, one,
# Nearest to while: which, to, in, as, an, able, and, instead,
# Nearest to is: a, the, in, or, an, with, and, as,
# Nearest to as: and, the, of, for, which, by, in, a,
# Nearest to three: two, five, four, one, nine, six, zero, eight,
# Nearest to seven: one, nine, zero, six, two, four, five, eight,
# Nearest to universe: pillars, wormhole, galaxies, novels, tilted, restated, africans, awestruck,
# Nearest to file: files, abstract, zealand, sinks, giantesses, format, meals, spaniel,
# Nearest to construction: lalr, tunnels, tighten, intrusions, tippi, revolving, dam, building,
# Nearest to bbc: external, february, january, december, news, listing, encyclopaedia, events,
# Nearest to issue: regarding, priority, tariff, djvu, frustrations, rok, wcw, pervasive,
# Nearest to bible: masoretic, mechon, lasor, tanakh, trademarked, hasmonaean, orsz, untranslated,
# Nearest to existence: bombers, ontological, anthropic, kali, moldova, personalized, elliptical, that,
# Nearest to primarily: fitna, mikado, ticino, rigorously, arabized, gnosticism, thai, supplying,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7442 0.0708 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7771 0.0685 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7285 0.0695 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8306 0.0693 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8068 0.0714 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7685 0.0690 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8712 0.0274 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7346 0.0706 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7727 0.0709 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7531 0.0717 sec/batch
# Nearest to they: them, teens, bereft, abandon, people, that, maynard, leto,
# Nearest to are: such, those, other, of, these, for, or, all,
# Nearest to six: four, five, zero, two, three, one, eight, nine,
# Nearest to while: which, as, in, an, to, able, this, endothelial,
# Nearest to is: a, in, the, or, with, an, and, there,
# Nearest to as: the, of, and, for, in, a, which, by,
# Nearest to three: two, five, four, one, nine, six, zero, eight,
# Nearest to seven: one, nine, six, two, four, zero, eight, five,
# Nearest to universe: pillars, wormhole, novels, tilted, galaxies, restated, africans, awestruck,
# Nearest to file: files, abstract, format, giantesses, zealand, documents, meals, compress,
# Nearest to construction: lalr, intrusions, tunnels, tighten, revolving, dam, building, tippi,
# Nearest to bbc: external, february, january, news, december, listing, encyclopaedia, day,
# Nearest to issue: frustrations, priority, tariff, rok, regarding, pervasive, djvu, wcw,
# Nearest to bible: masoretic, lasor, mechon, hasmonaean, trademarked, tanakh, orsz, untranslated,
# Nearest to existence: ontological, anthropic, bombers, kali, moldova, that, personalized, oakley,
# Nearest to primarily: fitna, rigorously, mikado, supplying, ticino, arabized, gnosticism, thai,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7889 0.0733 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7554 0.0721 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7796 0.0704 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7142 0.0708 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8008 0.0696 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7880 0.0701 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8085 0.0695 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7114 0.0701 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7370 0.0698 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7529 0.0702 sec/batch
# Nearest to they: them, teens, people, bereft, abandon, but, that, maynard,
# Nearest to are: such, other, those, of, and, all, or, for,
# Nearest to six: four, five, two, zero, three, eight, one, nine,
# Nearest to while: which, in, to, this, and, as, instead, are,
# Nearest to is: a, in, the, and, an, or, of, with,
# Nearest to as: the, of, and, for, in, which, a, by,
# Nearest to three: two, five, one, four, nine, six, zero, eight,
# Nearest to seven: one, nine, zero, two, six, four, eight, three,
# Nearest to universe: wormhole, pillars, galaxies, novels, tilted, restated, oscillatory, helium,
# Nearest to file: files, abstract, zealand, sinks, format, giantesses, documents, leaders,
# Nearest to construction: lalr, intrusions, tunnels, tighten, building, revolving, dam, tippi,
# Nearest to bbc: external, news, february, january, encyclopaedia, december, viewers, woe,
# Nearest to issue: frustrations, tariff, priority, regarding, djvu, pervasive, rok, mikael,
# Nearest to bible: masoretic, mechon, lasor, hasmonaean, tanakh, trademarked, orsz, haggai,
# Nearest to existence: ontological, bombers, kali, that, anthropic, moldova, personalized, theories,
# Nearest to primarily: fitna, rigorously, mikado, supplying, gnosticism, chang, arabized, ticino,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6824 0.0706 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7660 0.0704 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7884 0.0709 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7267 0.0693 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7483 0.0697 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8246 0.0710 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7899 0.0718 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7454 0.0698 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7655 0.0694 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7920 0.0692 sec/batch
# Nearest to they: them, teens, abandon, people, that, bereft, than, but,
# Nearest to are: such, other, those, of, or, all, for, these,
# Nearest to six: four, five, two, zero, three, eight, one, nine,
# Nearest to while: which, as, to, in, this, an, is, the,
# Nearest to is: a, in, the, an, and, or, as, with,
# Nearest to as: the, of, and, in, for, by, a, which,
# Nearest to three: two, five, one, four, six, zero, nine, eight,
# Nearest to seven: one, nine, zero, six, two, four, eight, five,
# Nearest to universe: wormhole, pillars, novels, tilted, galaxies, restated, africans, oscillatory,
# Nearest to file: files, abstract, zealand, sinks, giantesses, caprino, samples, shareware,
# Nearest to construction: lalr, tunnels, intrusions, building, tighten, revolving, dam, concrete,
# Nearest to bbc: external, february, news, december, january, viewers, encyclopaedia, woe,
# Nearest to issue: tariff, frustrations, djvu, priority, pervasive, mikael, uniformity, regarding,
# Nearest to bible: mechon, masoretic, lasor, hasmonaean, orsz, trademarked, tanakh, nadi,
# Nearest to existence: ontological, bombers, kali, moldova, anthropic, that, exists, momentous,
# Nearest to primarily: fitna, rigorously, mikado, gnosticism, arabized, ticino, chang, whistles,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8110 0.0725 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7576 0.0708 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7409 0.0710 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8051 0.0710 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7957 0.0695 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8102 0.0700 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7693 0.0691 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8057 0.0692 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7694 0.0701 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7604 0.0709 sec/batch
# Nearest to they: them, people, abandon, that, teens, than, leto, but,
# Nearest to are: other, such, those, or, for, all, of, and,
# Nearest to six: four, two, five, zero, three, eight, one, nine,
# Nearest to while: which, in, to, is, the, as, and, are,
# Nearest to is: a, in, the, an, and, or, with, for,
# Nearest to as: of, the, and, for, in, by, which, a,
# Nearest to three: two, five, one, four, six, nine, zero, eight,
# Nearest to seven: one, nine, two, six, four, zero, eight, five,
# Nearest to universe: wormhole, pillars, novels, tilted, galaxies, africans, restated, wormholes,
# Nearest to file: files, abstract, sinks, compress, zealand, giantesses, samples, coder,
# Nearest to construction: lalr, tunnels, intrusions, building, dam, tighten, revolving, tippi,
# Nearest to bbc: external, february, news, december, january, encyclopaedia, viewers, woe,
# Nearest to issue: tariff, regarding, priority, djvu, pervasive, mikael, frustrations, uniformity,
# Nearest to bible: mechon, masoretic, orsz, hasmonaean, lasor, untranslated, nadi, tanakh,
# Nearest to existence: ontological, bombers, kali, anthropic, moldova, that, heaven, oakley,
# Nearest to primarily: fitna, rigorously, mikado, gnosticism, thai, ticino, vcs, tagliatelle,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7818 0.0719 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7678 0.0711 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8438 0.0706 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8786 0.0703 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8291 0.0706 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7757 0.0704 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7078 0.0708 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7700 0.0711 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6640 0.0700 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8137 0.0701 sec/batch
# Nearest to they: them, teens, abandon, people, that, maynard, bereft, than,
# Nearest to are: such, other, or, those, of, all, these, for,
# Nearest to six: four, two, five, zero, three, nine, one, eight,
# Nearest to while: in, which, to, as, the, is, and, an,
# Nearest to is: a, in, the, an, or, and, with, as,
# Nearest to as: and, of, the, in, for, a, which, is,
# Nearest to three: two, one, five, four, nine, six, zero, eight,
# Nearest to seven: one, nine, two, six, four, eight, zero, five,
# Nearest to universe: pillars, wormhole, tilted, novels, restated, wormholes, africans, galaxies,
# Nearest to file: files, abstract, compress, format, zealand, giantesses, sinks, samples,
# Nearest to construction: lalr, intrusions, tunnels, tighten, tippi, building, dam, revolving,
# Nearest to bbc: external, february, news, january, december, encyclopaedia, viewers, woe,
# Nearest to issue: djvu, mikael, tariff, priority, frustrations, pervasive, regarding, rok,
# Nearest to bible: masoretic, mechon, lasor, orsz, hasmonaean, trademarked, untranslated, futurians,
# Nearest to existence: bombers, moldova, ontological, kali, anthropic, oakley, exists, garbled,
# Nearest to primarily: rigorously, fitna, mikado, gnosticism, thai, chang, arabized, level,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7695 0.0711 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7577 0.0719 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
